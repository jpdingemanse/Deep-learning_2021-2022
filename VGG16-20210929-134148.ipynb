# %%
import imageio
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
##Path for Training data
path = "C:/Users/karni/Documents/Data Science and Society Coursework/Blok 1/Deep Learning/Assignment/Train Data set/Train/Train/"
##Path for Validation data
path2 = "C:/Users/karni/Documents/Data Science and Society Coursework/Blok 1/Deep Learning/Assignment/Train Data set/Test/Test/"

# %%
genders = ['Male', 'Female']
frmt = "png"

# %%
def imgtodataset(path, genders, frmt):
    data_l = []
    label_l = []
    
    for i in range(len(genders)):
        for im_path in glob.glob(path + genders[i] + "/*." + frmt):
            im = imageio.imread(im_path)
            arr = np.array(im)
            data_l.append(arr)
            label_l.append(i)

    data = np.array(data_l)
    label = np.array(label_l)        
    
    return data, label

# %%
data, label = imgtodataset(path, genders, frmt)

# %%
val_data, val_label = imgtodataset(path2, genders, frmt)

# %%
#Preprocessing data

# %%
data_pp = tf.keras.applications.vgg16.preprocess_input(
        data, data_format=None
    )

# %%
val_data_pp =  tf.keras.applications.vgg16.preprocess_input(
        val_data, data_format=None
    )

# %%
base_vgg_model = tf.keras.applications.vgg16.VGG16(
    include_top=False, weights='imagenet', input_tensor=None,
    input_shape=(100,100,3), pooling=max, classes=2)

# %%
base_vgg_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_vgg_model.trainable = False

# %%
inputs = keras.Input(shape=(100, 100, 3))

# %%
x = base_vgg_model(inputs, training=False)

# %%
x = keras.layers.Flatten()(x)

# %%
## Defining the number of epochs
epochs_range = 20

# %%
##Building competing models

# %%
x_1 = keras.layers.Dense(64, activation='relu')(x)
outputs_1 = keras.layers.Dense(1, activation='sigmoid')(x_1)
model_1_1 = keras.Model(inputs, outputs_1)

# %%
model_1_1.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Accuracy(), keras.metrics.AUC(), keras.metrics.Precision(),keras.metrics.Recall(), 
                      keras.metrics.TruePositives(), keras.metrics.TrueNegatives(), keras.metrics.FalsePositives(), 
                    keras.metrics.FalseNegatives()])

# %%
history_1_1 = model_1_1.fit(data_pp, label, epochs=epochs_range, validation_data=(val_data_pp, val_label))
# Out:
# Epoch 1/8
# 348/348 [==============================] - 341s 976ms/step - loss: 3.2038 - binary_accuracy: 0.8392 - accuracy: 0.3535 - auc_3: 0.8625 - precision_3: 0.8272 - recall_3: 0.8296 - true_positives_3: 4323.0000 - true_negatives_3: 5021.0000 - false_positives_3: 903.0000 - false_negatives_3: 888.0000 - val_loss: 1.6635 - val_binary_accuracy: 0.8577 - val_accuracy: 0.1493 - val_auc_3: 0.8782 - val_precision_3: 0.9211 - val_recall_3: 0.6972 - val_true_positives_3: 350.0000 - val_true_negatives_3: 747.0000 - val_false_positives_3: 30.0000 - val_false_negatives_3: 152.0000
# Epoch 2/8
# 348/348 [==============================] - 352s 1s/step - loss: 0.5370 - binary_accuracy: 0.8965 - accuracy: 0.1422 - auc_3: 0.9442 - precision_3: 0.8919 - recall_3: 0.8862 - true_positives_3: 4618.0000 - true_negatives_3: 5364.0000 - false_positives_3: 560.0000 - false_negatives_3: 593.0000 - val_loss: 0.5334 - val_binary_accuracy: 0.8749 - val_accuracy: 0.0211 - val_auc_3: 0.9299 - val_precision_3: 0.8685 - val_recall_3: 0.8028 - val_true_positives_3: 403.0000 - val_true_negatives_3: 716.0000 - val_false_positives_3: 61.0000 - val_false_negatives_3: 99.0000
# Epoch 3/8
# 348/348 [==============================] - 342s 982ms/step - loss: 0.2063 - binary_accuracy: 0.9255 - accuracy: 0.0151 - auc_3: 0.9758 - precision_3: 0.9239 - recall_3: 0.9161 - true_positives_3: 4774.0000 - true_negatives_3: 5531.0000 - false_positives_3: 393.0000 - false_negatives_3: 437.0000 - val_loss: 0.4099 - val_binary_accuracy: 0.8726 - val_accuracy: 0.0039 - val_auc_3: 0.9317 - val_precision_3: 0.8204 - val_recall_3: 0.8645 - val_true_positives_3: 434.0000 - val_true_negatives_3: 682.0000 - val_false_positives_3: 95.0000 - val_false_negatives_3: 68.0000
# Epoch 4/8
# 348/348 [==============================] - 337s 968ms/step - loss: 0.1668 - binary_accuracy: 0.9355 - accuracy: 0.0058 - auc_3: 0.9825 - precision_3: 0.9366 - recall_3: 0.9248 - true_positives_3: 4819.0000 - true_negatives_3: 5598.0000 - false_positives_3: 326.0000 - false_negatives_3: 392.0000 - val_loss: 0.4017 - val_binary_accuracy: 0.8804 - val_accuracy: 0.0047 - val_auc_3: 0.9378 - val_precision_3: 0.8753 - val_recall_3: 0.8108 - val_true_positives_3: 407.0000 - val_true_negatives_3: 719.0000 - val_false_positives_3: 58.0000 - val_false_negatives_3: 95.0000
# Epoch 5/8
# 348/348 [==============================] - 426s 1s/step - loss: 0.1567 - binary_accuracy: 0.9397 - accuracy: 0.0073 - auc_3: 0.9844 - precision_3: 0.9399 - recall_3: 0.9307 - true_positives_3: 4850.0000 - true_negatives_3: 5614.0000 - false_positives_3: 310.0000 - false_negatives_3: 361.0000 - val_loss: 0.3893 - val_binary_accuracy: 0.8726 - val_accuracy: 0.0031 - val_auc_3: 0.9360 - val_precision_3: 0.8709 - val_recall_3: 0.7928 - val_true_positives_3: 398.0000 - val_true_negatives_3: 718.0000 - val_false_positives_3: 59.0000 - val_false_negatives_3: 104.0000
# Epoch 6/8
# 348/348 [==============================] - 331s 951ms/step - loss: 0.1574 - binary_accuracy: 0.9405 - accuracy: 0.0082 - auc_3: 0.9844 - precision_3: 0.9412 - recall_3: 0.9309 - true_positives_3: 4851.0000 - true_negatives_3: 5621.0000 - false_positives_3: 303.0000 - false_negatives_3: 360.0000 - val_loss: 0.4254 - val_binary_accuracy: 0.8804 - val_accuracy: 0.0078 - val_auc_3: 0.9316 - val_precision_3: 0.8598 - val_recall_3: 0.8307 - val_true_positives_3: 417.0000 - val_true_negatives_3: 709.0000 - val_false_positives_3: 68.0000 - val_false_negatives_3: 85.0000
# Epoch 7/8
# 348/348 [==============================] - 376s 1s/step - loss: 0.1538 - binary_accuracy: 0.9408 - accuracy: 0.0114 - auc_3: 0.9853 - precision_3: 0.9399 - recall_3: 0.9332 - true_positives_3: 4863.0000 - true_negatives_3: 5613.0000 - false_positives_3: 311.0000 - false_negatives_3: 348.0000 - val_loss: 0.4429 - val_binary_accuracy: 0.8561 - val_accuracy: 0.0055 - val_auc_3: 0.9279 - val_precision_3: 0.7860 - val_recall_3: 0.8705 - val_true_positives_3: 437.0000 - val_true_negatives_3: 658.0000 - val_false_positives_3: 119.0000 - val_false_negatives_3: 65.0000
# Epoch 8/8
# 348/348 [==============================] - 324s 931ms/step - loss: 0.1636 - binary_accuracy: 0.9397 - accuracy: 0.0095 - auc_3: 0.9833 - precision_3: 0.9386 - recall_3: 0.9323 - true_positives_3: 4858.0000 - true_negatives_3: 5606.0000 - false_positives_3: 318.0000 - false_negatives_3: 353.0000 - val_loss: 0.4368 - val_binary_accuracy: 0.8522 - val_accuracy: 0.0047 - val_auc_3: 0.9277 - val_precision_3: 0.7780 - val_recall_3: 0.8725 - val_true_positives_3: 438.0000 - val_true_negatives_3: 652.0000 - val_false_positives_3: 125.0000 - val_false_negatives_3: 64.0000

# %%
model_1_1.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 3, 3, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                294976
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 15,009,729
# Trainable params: 295,041
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
history_1_1.history
# Out:
# {'loss': [3.203836679458618,
#   0.5370157361030579,
#   0.20629501342773438,
#   0.16684956848621368,
#   0.15673168003559113,
#   0.15735876560211182,
#   0.15376827120780945,
#   0.16359087824821472],
#  'binary_accuracy': [0.8391557931900024,
#   0.8964526057243347,
#   0.9254602789878845,
#   0.9355186223983765,
#   0.9397395849227905,
#   0.9404579997062683,
#   0.9408172369003296,
#   0.9397395849227905],
#  'accuracy': [0.3534800112247467,
#   0.14216434955596924,
#   0.015087561681866646,
#   0.005837449338287115,
#   0.007274359930306673,
#   0.008172429166734219,
#   0.011405478231608868,
#   0.00951953325420618],
#  'auc_3': [0.8625208735466003,
#   0.9442067742347717,
#   0.9757828712463379,
#   0.9824899435043335,
#   0.9844189882278442,
#   0.9844139218330383,
#   0.9853391051292419,
#   0.9832614660263062],
#  'precision_3': [0.8272101283073425,
#   0.8918501138687134,
#   0.9239404201507568,
#   0.9366375207901001,
#   0.9399224519729614,
#   0.9412106871604919,
#   0.9398917555809021,
#   0.9385625720024109],
#  'recall_3': [0.8295912742614746,
#   0.8862022757530212,
#   0.9161389470100403,
#   0.9247745275497437,
#   0.9307234883308411,
#   0.930915355682373,
#   0.9332181811332703,
#   0.932258665561676],
#  'true_positives_3': [4323.0,
#   4618.0,
#   4774.0,
#   4819.0,
#   4850.0,
#   4851.0,
#   4863.0,
#   4858.0],
#  'true_negatives_3': [5021.0,
#   5364.0,
#   5531.0,
#   5598.0,
#   5614.0,
#   5621.0,
#   5613.0,
#   5606.0],
#  'false_positives_3': [903.0, 560.0, 393.0, 326.0, 310.0, 303.0, 311.0, 318.0],
#  'false_negatives_3': [888.0, 593.0, 437.0, 392.0, 361.0, 360.0, 348.0, 353.0],
#  'val_loss': [1.663468837738037,
#   0.5334312319755554,
#   0.4099498987197876,
#   0.40167373418807983,
#   0.38926246762275696,
#   0.42540839314460754,
#   0.4429398477077484,
#   0.4368096590042114],
#  'val_binary_accuracy': [0.857701301574707,
#   0.8749022483825684,
#   0.8725566864013672,
#   0.8803752660751343,
#   0.8725566864013672,
#   0.8803752660751343,
#   0.8561376333236694,
#   0.8522282838821411],
#  'val_accuracy': [0.14933541417121887,
#   0.02111024223268032,
#   0.0039093042723834515,
#   0.004691164940595627,
#   0.0031274433713406324,
#   0.007818608544766903,
#   0.005473025608807802,
#   0.004691164940595627],
#  'val_auc_3': [0.8781949877738953,
#   0.9299147725105286,
#   0.9316580891609192,
#   0.9377636909484863,
#   0.9359781742095947,
#   0.931602954864502,
#   0.9278548359870911,
#   0.9277150630950928],
#  'val_precision_3': [0.9210526347160339,
#   0.868534505367279,
#   0.8204158544540405,
#   0.875268816947937,
#   0.8708971738815308,
#   0.8597938418388367,
#   0.7859712243080139,
#   0.7779751420021057],
#  'val_recall_3': [0.6972111463546753,
#   0.8027888536453247,
#   0.8645418286323547,
#   0.8107569813728333,
#   0.7928286790847778,
#   0.8306772708892822,
#   0.870517909526825,
#   0.8725099563598633],
#  'val_true_positives_3': [350.0,
#   403.0,
#   434.0,
#   407.0,
#   398.0,
#   417.0,
#   437.0,
#   438.0],
#  'val_true_negatives_3': [747.0,
#   716.0,
#   682.0,
#   719.0,
#   718.0,
#   709.0,
#   658.0,
#   652.0],
#  'val_false_positives_3': [30.0, 61.0, 95.0, 58.0, 59.0, 68.0, 119.0, 125.0],
#  'val_false_negatives_3': [152.0, 99.0, 68.0, 95.0, 104.0, 85.0, 65.0, 64.0]}

# %%
# list all data in history
print(history_1_1.history.keys())
# Out:
# dict_keys(['loss', 'binary_accuracy', 'accuracy', 'auc_3', 'precision_3', 'recall_3', 'true_positives_3', 'true_negatives_3', 'false_positives_3', 'false_negatives_3', 'val_loss', 'val_binary_accuracy', 'val_accuracy', 'val_auc_3', 'val_precision_3', 'val_recall_3', 'val_true_positives_3', 'val_true_negatives_3', 'val_false_positives_3', 'val_false_negatives_3'])

# %%
# summarize history for accuracy
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(history_1_1.history['binary_accuracy'], label='Training Accuracy')
plt.plot(history_1_1.history['val_binary_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Binary Accuracy for Model')

plt.subplot(1, 2, 2)
plt.plot(history_1_1.history['loss'], label='Training Loss')
plt.plot(history_1_1.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss for Model')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss for Model 1.1')

# %%
plt.plot(history_1_1.history['auc_3'], label='Training AUC for ROC')
plt.plot(history_1_1.history['val_auc_3'], label='Validation AUC for ROC')
plt.legend(loc='lower right')
plt.title('Training and Validation AUC')
# Out:
# Text(0.5, 1.0, 'Training and Validation AUC')

# %%
def getresultssummary(mod_history, mod_num):
    # summarize history for accuracy
    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(mod_history.history['binary_accuracy'], label='Training Accuracy')
    plt.plot(mod_history.history['val_binary_accuracy'], label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Binary Accuracy for Model '+mod_num)

    plt.subplot(1, 2, 2)
    plt.plot(mod_history.history['loss'], label='Training Loss')
    plt.plot(mod_history.history['val_loss'], label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss for Model '+ mod_num)

# %%
model_1_2 = keras.Model(inputs, outputs_1)
model_1_2.compile(optimizer=keras.optimizers.SGD(),
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Accuracy(), keras.metrics.AUC(), keras.metrics.Precision(),keras.metrics.Recall(), 
                      keras.metrics.TruePositives(), keras.metrics.TrueNegatives(), keras.metrics.FalsePositives(), 
                    keras.metrics.FalseNegatives()])

# %%
history_1_2 = model_1_2.fit(data_pp, label, epochs=epochs_range, validation_data=(val_data_pp, val_label))
# Out:
# Epoch 1/20
# 348/348 [==============================] - 307s 877ms/step - loss: 0.5816 - binary_accuracy: 0.8663 - accuracy: 0.0017 - auc: 0.9319 - precision: 0.8628 - recall: 0.8494 - true_positives: 4426.0000 - true_negatives: 5220.0000 - false_positives: 704.0000 - false_negatives: 785.0000 - val_loss: 0.2748 - val_binary_accuracy: 0.8882 - val_accuracy: 0.0000e+00 - val_auc: 0.9502 - val_precision: 0.8811 - val_recall: 0.8267 - val_true_positives: 415.0000 - val_true_negatives: 721.0000 - val_false_positives: 56.0000 - val_false_negatives: 87.0000
# Epoch 2/20
# 348/348 [==============================] - 328s 943ms/step - loss: 0.2628 - binary_accuracy: 0.8918 - accuracy: 0.0000e+00 - auc: 0.9575 - precision: 0.8946 - recall: 0.8714 - true_positives: 4541.0000 - true_negatives: 5389.0000 - false_positives: 535.0000 - false_negatives: 670.0000 - val_loss: 0.2906 - val_binary_accuracy: 0.8944 - val_accuracy: 0.0000e+00 - val_auc: 0.9552 - val_precision: 0.9180 - val_recall: 0.8028 - val_true_positives: 403.0000 - val_true_negatives: 741.0000 - val_false_positives: 36.0000 - val_false_negatives: 99.0000
# Epoch 3/20
# 348/348 [==============================] - 326s 936ms/step - loss: 0.2342 - binary_accuracy: 0.9046 - accuracy: 4.4903e-04 - auc: 0.9660 - precision: 0.9148 - recall: 0.8780 - true_positives: 4575.0000 - true_negatives: 5498.0000 - false_positives: 426.0000 - false_negatives: 636.0000 - val_loss: 0.2723 - val_binary_accuracy: 0.8968 - val_accuracy: 0.0000e+00 - val_auc: 0.9531 - val_precision: 0.8870 - val_recall: 0.8446 - val_true_positives: 424.0000 - val_true_negatives: 723.0000 - val_false_positives: 54.0000 - val_false_negatives: 78.0000
# Epoch 4/20
# 348/348 [==============================] - 3607s 10s/step - loss: 0.2156 - binary_accuracy: 0.9117 - accuracy: 3.5923e-04 - auc: 0.9709 - precision: 0.9168 - recall: 0.8923 - true_positives: 4650.0000 - true_negatives: 5502.0000 - false_positives: 422.0000 - false_negatives: 561.0000 - val_loss: 0.3077 - val_binary_accuracy: 0.8929 - val_accuracy: 7.8186e-04 - val_auc: 0.9525 - val_precision: 0.8489 - val_recall: 0.8845 - val_true_positives: 444.0000 - val_true_negatives: 698.0000 - val_false_positives: 79.0000 - val_false_negatives: 58.0000
# Epoch 5/20
# 348/348 [==============================] - 326s 938ms/step - loss: 0.1898 - binary_accuracy: 0.9220 - accuracy: 0.0017 - auc: 0.9776 - precision: 0.9269 - recall: 0.9048 - true_positives: 4715.0000 - true_negatives: 5552.0000 - false_positives: 372.0000 - false_negatives: 496.0000 - val_loss: 0.2783 - val_binary_accuracy: 0.8944 - val_accuracy: 0.0000e+00 - val_auc: 0.9540 - val_precision: 0.9105 - val_recall: 0.8108 - val_true_positives: 407.0000 - val_true_negatives: 737.0000 - val_false_positives: 40.0000 - val_false_negatives: 95.0000
# Epoch 6/20
# 348/348 [==============================] - 336s 965ms/step - loss: 0.1759 - binary_accuracy: 0.9267 - accuracy: 0.0023 - auc: 0.9806 - precision: 0.9351 - recall: 0.9064 - true_positives: 4723.0000 - true_negatives: 5596.0000 - false_positives: 328.0000 - false_negatives: 488.0000 - val_loss: 0.3213 - val_binary_accuracy: 0.8905 - val_accuracy: 0.0031 - val_auc: 0.9458 - val_precision: 0.8620 - val_recall: 0.8586 - val_true_positives: 431.0000 - val_true_negatives: 708.0000 - val_false_positives: 69.0000 - val_false_negatives: 71.0000
# Epoch 7/20
# 348/348 [==============================] - 338s 971ms/step - loss: 0.1580 - binary_accuracy: 0.9338 - accuracy: 0.0039 - auc: 0.9843 - precision: 0.9397 - recall: 0.9175 - true_positives: 4781.0000 - true_negatives: 5617.0000 - false_positives: 307.0000 - false_negatives: 430.0000 - val_loss: 0.3264 - val_binary_accuracy: 0.8929 - val_accuracy: 7.8186e-04 - val_auc: 0.9481 - val_precision: 0.8875 - val_recall: 0.8327 - val_true_positives: 418.0000 - val_true_negatives: 724.0000 - val_false_positives: 53.0000 - val_false_negatives: 84.0000
# Epoch 8/20
# 348/348 [==============================] - 337s 968ms/step - loss: 0.1424 - binary_accuracy: 0.9410 - accuracy: 0.0123 - auc: 0.9874 - precision: 0.9481 - recall: 0.9246 - true_positives: 4818.0000 - true_negatives: 5660.0000 - false_positives: 264.0000 - false_negatives: 393.0000 - val_loss: 0.4137 - val_binary_accuracy: 0.8726 - val_accuracy: 0.0281 - val_auc: 0.9427 - val_precision: 0.8087 - val_recall: 0.8845 - val_true_positives: 444.0000 - val_true_negatives: 672.0000 - val_false_positives: 105.0000 - val_false_negatives: 58.0000
# Epoch 9/20
# 348/348 [==============================] - 336s 967ms/step - loss: 0.1332 - binary_accuracy: 0.9474 - accuracy: 0.0157 - auc: 0.9887 - precision: 0.9509 - recall: 0.9359 - true_positives: 4877.0000 - true_negatives: 5672.0000 - false_positives: 252.0000 - false_negatives: 334.0000 - val_loss: 0.3499 - val_binary_accuracy: 0.9030 - val_accuracy: 0.0203 - val_auc: 0.9468 - val_precision: 0.8954 - val_recall: 0.8526 - val_true_positives: 428.0000 - val_true_negatives: 727.0000 - val_false_positives: 50.0000 - val_false_negatives: 74.0000
# Epoch 10/20
# 348/348 [==============================] - 336s 967ms/step - loss: 0.1229 - binary_accuracy: 0.9514 - accuracy: 0.0255 - auc: 0.9903 - precision: 0.9534 - recall: 0.9422 - true_positives: 4910.0000 - true_negatives: 5684.0000 - false_positives: 240.0000 - false_negatives: 301.0000 - val_loss: 0.4068 - val_binary_accuracy: 0.8858 - val_accuracy: 0.0297 - val_auc: 0.9385 - val_precision: 0.8463 - val_recall: 0.8665 - val_true_positives: 435.0000 - val_true_negatives: 698.0000 - val_false_positives: 79.0000 - val_false_negatives: 67.0000
# Epoch 11/20
# 348/348 [==============================] - 336s 966ms/step - loss: 0.1049 - binary_accuracy: 0.9576 - accuracy: 0.0356 - auc: 0.9929 - precision: 0.9618 - recall: 0.9470 - true_positives: 4935.0000 - true_negatives: 5728.0000 - false_positives: 196.0000 - false_negatives: 276.0000 - val_loss: 0.3816 - val_binary_accuracy: 0.8827 - val_accuracy: 0.0180 - val_auc: 0.9390 - val_precision: 0.8667 - val_recall: 0.8287 - val_true_positives: 416.0000 - val_true_negatives: 713.0000 - val_false_positives: 64.0000 - val_false_negatives: 86.0000
# Epoch 12/20
# 348/348 [==============================] - 337s 968ms/step - loss: 0.0985 - binary_accuracy: 0.9587 - accuracy: 0.0571 - auc: 0.9937 - precision: 0.9614 - recall: 0.9499 - true_positives: 4950.0000 - true_negatives: 5725.0000 - false_positives: 199.0000 - false_negatives: 261.0000 - val_loss: 0.4071 - val_binary_accuracy: 0.8812 - val_accuracy: 0.0336 - val_auc: 0.9417 - val_precision: 0.8661 - val_recall: 0.8247 - val_true_positives: 414.0000 - val_true_negatives: 713.0000 - val_false_positives: 64.0000 - val_false_negatives: 88.0000
# Epoch 13/20
# 348/348 [==============================] - 337s 968ms/step - loss: 0.0866 - binary_accuracy: 0.9652 - accuracy: 0.0599 - auc: 0.9949 - precision: 0.9671 - recall: 0.9582 - true_positives: 4993.0000 - true_negatives: 5754.0000 - false_positives: 170.0000 - false_negatives: 218.0000 - val_loss: 0.4291 - val_binary_accuracy: 0.8843 - val_accuracy: 0.0665 - val_auc: 0.9405 - val_precision: 0.8512 - val_recall: 0.8546 - val_true_positives: 429.0000 - val_true_negatives: 702.0000 - val_false_positives: 75.0000 - val_false_negatives: 73.0000
# Epoch 14/20
# 348/348 [==============================] - 336s 966ms/step - loss: 0.0816 - binary_accuracy: 0.9685 - accuracy: 0.0759 - auc: 0.9955 - precision: 0.9715 - recall: 0.9609 - true_positives: 5007.0000 - true_negatives: 5777.0000 - false_positives: 147.0000 - false_negatives: 204.0000 - val_loss: 0.4718 - val_binary_accuracy: 0.8851 - val_accuracy: 0.0508 - val_auc: 0.9282 - val_precision: 0.8630 - val_recall: 0.8406 - val_true_positives: 422.0000 - val_true_negatives: 710.0000 - val_false_positives: 67.0000 - val_false_negatives: 80.0000
# Epoch 15/20
# 348/348 [==============================] - 342s 982ms/step - loss: 0.0724 - binary_accuracy: 0.9705 - accuracy: 0.0877 - auc: 0.9963 - precision: 0.9743 - recall: 0.9622 - true_positives: 5014.0000 - true_negatives: 5792.0000 - false_positives: 132.0000 - false_negatives: 197.0000 - val_loss: 0.5076 - val_binary_accuracy: 0.8843 - val_accuracy: 0.0594 - val_auc: 0.9337 - val_precision: 0.8627 - val_recall: 0.8386 - val_true_positives: 421.0000 - val_true_negatives: 710.0000 - val_false_positives: 67.0000 - val_false_negatives: 81.0000
# Epoch 16/20
# 348/348 [==============================] - 342s 982ms/step - loss: 0.0625 - binary_accuracy: 0.9758 - accuracy: 0.0977 - auc: 0.9973 - precision: 0.9791 - recall: 0.9689 - true_positives: 5049.0000 - true_negatives: 5816.0000 - false_positives: 108.0000 - false_negatives: 162.0000 - val_loss: 0.5654 - val_binary_accuracy: 0.8921 - val_accuracy: 0.0618 - val_auc: 0.9328 - val_precision: 0.8939 - val_recall: 0.8227 - val_true_positives: 413.0000 - val_true_negatives: 728.0000 - val_false_positives: 49.0000 - val_false_negatives: 89.0000
# Epoch 17/20
# 348/348 [==============================] - 338s 972ms/step - loss: 0.0694 - binary_accuracy: 0.9740 - accuracy: 0.1037 - auc: 0.9964 - precision: 0.9762 - recall: 0.9680 - true_positives: 5044.0000 - true_negatives: 5801.0000 - false_positives: 123.0000 - false_negatives: 167.0000 - val_loss: 0.5367 - val_binary_accuracy: 0.8804 - val_accuracy: 0.0649 - val_auc: 0.9297 - val_precision: 0.8721 - val_recall: 0.8147 - val_true_positives: 409.0000 - val_true_negatives: 717.0000 - val_false_positives: 60.0000 - val_false_negatives: 93.0000
# Epoch 18/20
# 348/348 [==============================] - 338s 971ms/step - loss: 0.0551 - binary_accuracy: 0.9784 - accuracy: 0.1085 - auc: 0.9979 - precision: 0.9812 - recall: 0.9724 - true_positives: 5067.0000 - true_negatives: 5827.0000 - false_positives: 97.0000 - false_negatives: 144.0000 - val_loss: 0.5661 - val_binary_accuracy: 0.8772 - val_accuracy: 0.0844 - val_auc: 0.9192 - val_precision: 0.8499 - val_recall: 0.8347 - val_true_positives: 419.0000 - val_true_negatives: 703.0000 - val_false_positives: 74.0000 - val_false_negatives: 83.0000
# Epoch 19/20
# 348/348 [==============================] - 338s 971ms/step - loss: 0.0486 - binary_accuracy: 0.9818 - accuracy: 0.1214 - auc: 0.9980 - precision: 0.9836 - recall: 0.9774 - true_positives: 5093.0000 - true_negatives: 5839.0000 - false_positives: 85.0000 - false_negatives: 118.0000 - val_loss: 0.5451 - val_binary_accuracy: 0.8796 - val_accuracy: 0.0813 - val_auc: 0.9232 - val_precision: 0.8551 - val_recall: 0.8347 - val_true_positives: 419.0000 - val_true_negatives: 706.0000 - val_false_positives: 71.0000 - val_false_negatives: 83.0000
# Epoch 20/20
# 348/348 [==============================] - 338s 971ms/step - loss: 0.0410 - binary_accuracy: 0.9851 - accuracy: 0.1309 - auc: 0.9987 - precision: 0.9871 - recall: 0.9810 - true_positives: 5112.0000 - true_negatives: 5857.0000 - false_positives: 67.0000 - false_negatives: 99.0000 - val_loss: 0.5672 - val_binary_accuracy: 0.8780 - val_accuracy: 0.1079 - val_auc: 0.9317 - val_precision: 0.8560 - val_recall: 0.8287 - val_true_positives: 416.0000 - val_true_negatives: 707.0000 - val_false_positives: 70.0000 - val_false_negatives: 86.0000

# %%
getresultssummary(history_1_2, '1.2')

# %%
x_2 = keras.layers.Dense(256, activation= 'relu')(x)
x_2 = keras.layers.Dense(128, activation= 'relu')(x_2)
outputs_2 = keras.layers.Dense(1, activation='sigmoid')(x_2)
model_2 = keras.Model(inputs, outputs_2)

# %%
model_2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 3, 3, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 15,927,617
# Trainable params: 1,212,929
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model_2.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Accuracy(), keras.metrics.AUC(), keras.metrics.Precision(),keras.metrics.Recall(), 
                      keras.metrics.TruePositives(), keras.metrics.TrueNegatives(), keras.metrics.FalsePositives(), 
                    keras.metrics.FalseNegatives()])

# %%
history_2 = model_2.fit(data_pp, label, epochs=epochs_range, validation_data=(val_data_pp, val_label))
# Out:
# Epoch 1/20
# 348/348 [==============================] - 327s 936ms/step - loss: 0.5028 - binary_accuracy: 0.8514 - accuracy: 0.0163 - auc_1: 0.9173 - precision_1: 0.8469 - recall_1: 0.8330 - true_positives_1: 4341.0000 - true_negatives_1: 5139.0000 - false_positives_1: 785.0000 - false_negatives_1: 870.0000 - val_loss: 0.3074 - val_binary_accuracy: 0.8827 - val_accuracy: 0.0031 - val_auc_1: 0.9449 - val_precision_1: 0.8929 - val_recall_1: 0.7968 - val_true_positives_1: 400.0000 - val_true_negatives_1: 729.0000 - val_false_positives_1: 48.0000 - val_false_negatives_1: 102.0000
# Epoch 2/20
# 348/348 [==============================] - 329s 946ms/step - loss: 0.2426 - binary_accuracy: 0.9058 - accuracy: 0.0074 - auc_1: 0.9667 - precision_1: 0.9074 - recall_1: 0.8895 - true_positives_1: 4635.0000 - true_negatives_1: 5451.0000 - false_positives_1: 473.0000 - false_negatives_1: 576.0000 - val_loss: 0.3647 - val_binary_accuracy: 0.8812 - val_accuracy: 0.0078 - val_auc_1: 0.9397 - val_precision_1: 0.8772 - val_recall_1: 0.8108 - val_true_positives_1: 407.0000 - val_true_negatives_1: 720.0000 - val_false_positives_1: 57.0000 - val_false_negatives_1: 95.0000
# Epoch 3/20
# 348/348 [==============================] - 332s 956ms/step - loss: 0.1731 - binary_accuracy: 0.9348 - accuracy: 0.0163 - auc_1: 0.9823 - precision_1: 0.9338 - recall_1: 0.9263 - true_positives_1: 4827.0000 - true_negatives_1: 5582.0000 - false_positives_1: 342.0000 - false_negatives_1: 384.0000 - val_loss: 0.3945 - val_binary_accuracy: 0.8851 - val_accuracy: 0.0328 - val_auc_1: 0.9452 - val_precision_1: 0.8460 - val_recall_1: 0.8645 - val_true_positives_1: 434.0000 - val_true_negatives_1: 698.0000 - val_false_positives_1: 79.0000 - val_false_negatives_1: 68.0000
# Epoch 4/20
# 348/348 [==============================] - 335s 962ms/step - loss: 0.1380 - binary_accuracy: 0.9512 - accuracy: 0.0430 - auc_1: 0.9889 - precision_1: 0.9516 - recall_1: 0.9438 - true_positives_1: 4918.0000 - true_negatives_1: 5674.0000 - false_positives_1: 250.0000 - false_negatives_1: 293.0000 - val_loss: 0.4175 - val_binary_accuracy: 0.8671 - val_accuracy: 0.0297 - val_auc_1: 0.9321 - val_precision_1: 0.8307 - val_recall_1: 0.8307 - val_true_positives_1: 417.0000 - val_true_negatives_1: 692.0000 - val_false_positives_1: 85.0000 - val_false_negatives_1: 85.0000
# Epoch 5/20
# 348/348 [==============================] - 332s 954ms/step - loss: 0.0973 - binary_accuracy: 0.9689 - accuracy: 0.0717 - auc_1: 0.9936 - precision_1: 0.9672 - recall_1: 0.9664 - true_positives_1: 5036.0000 - true_negatives_1: 5753.0000 - false_positives_1: 171.0000 - false_negatives_1: 175.0000 - val_loss: 0.4945 - val_binary_accuracy: 0.8804 - val_accuracy: 0.0555 - val_auc_1: 0.9309 - val_precision_1: 0.8886 - val_recall_1: 0.7948 - val_true_positives_1: 399.0000 - val_true_negatives_1: 727.0000 - val_false_positives_1: 50.0000 - val_false_negatives_1: 103.0000
# Epoch 6/20
# 348/348 [==============================] - 331s 952ms/step - loss: 0.0888 - binary_accuracy: 0.9724 - accuracy: 0.0697 - auc_1: 0.9950 - precision_1: 0.9710 - recall_1: 0.9701 - true_positives_1: 5055.0000 - true_negatives_1: 5773.0000 - false_positives_1: 151.0000 - false_negatives_1: 156.0000 - val_loss: 0.4988 - val_binary_accuracy: 0.8858 - val_accuracy: 0.0414 - val_auc_1: 0.9321 - val_precision_1: 0.8693 - val_recall_1: 0.8347 - val_true_positives_1: 419.0000 - val_true_negatives_1: 714.0000 - val_false_positives_1: 63.0000 - val_false_negatives_1: 83.0000
# Epoch 7/20
# 348/348 [==============================] - 332s 954ms/step - loss: 0.0660 - binary_accuracy: 0.9800 - accuracy: 0.0906 - auc_1: 0.9961 - precision_1: 0.9791 - recall_1: 0.9781 - true_positives_1: 5097.0000 - true_negatives_1: 5815.0000 - false_positives_1: 109.0000 - false_negatives_1: 114.0000 - val_loss: 0.5858 - val_binary_accuracy: 0.8679 - val_accuracy: 0.0665 - val_auc_1: 0.9259 - val_precision_1: 0.8271 - val_recall_1: 0.8386 - val_true_positives_1: 421.0000 - val_true_negatives_1: 689.0000 - val_false_positives_1: 88.0000 - val_false_negatives_1: 81.0000
# Epoch 8/20
# 348/348 [==============================] - 333s 958ms/step - loss: 0.0801 - binary_accuracy: 0.9755 - accuracy: 0.1174 - auc_1: 0.9951 - precision_1: 0.9748 - recall_1: 0.9727 - true_positives_1: 5069.0000 - true_negatives_1: 5793.0000 - false_positives_1: 131.0000 - false_negatives_1: 142.0000 - val_loss: 0.5224 - val_binary_accuracy: 0.8780 - val_accuracy: 0.0868 - val_auc_1: 0.9367 - val_precision_1: 0.8168 - val_recall_1: 0.8884 - val_true_positives_1: 446.0000 - val_true_negatives_1: 677.0000 - val_false_positives_1: 100.0000 - val_false_negatives_1: 56.0000
# Epoch 9/20
# 348/348 [==============================] - 332s 955ms/step - loss: 0.0600 - binary_accuracy: 0.9841 - accuracy: 0.1247 - auc_1: 0.9973 - precision_1: 0.9833 - recall_1: 0.9827 - true_positives_1: 5121.0000 - true_negatives_1: 5837.0000 - false_positives_1: 87.0000 - false_negatives_1: 90.0000 - val_loss: 0.7319 - val_binary_accuracy: 0.8843 - val_accuracy: 0.0493 - val_auc_1: 0.9201 - val_precision_1: 0.9078 - val_recall_1: 0.7849 - val_true_positives_1: 394.0000 - val_true_negatives_1: 737.0000 - val_false_positives_1: 40.0000 - val_false_negatives_1: 108.0000
# Epoch 10/20
# 348/348 [==============================] - 1424s 4s/step - loss: 0.0593 - binary_accuracy: 0.9859 - accuracy: 0.1383 - auc_1: 0.9967 - precision_1: 0.9856 - recall_1: 0.9843 - true_positives_1: 5129.0000 - true_negatives_1: 5849.0000 - false_positives_1: 75.0000 - false_negatives_1: 82.0000 - val_loss: 0.5938 - val_binary_accuracy: 0.8835 - val_accuracy: 0.0790 - val_auc_1: 0.9269 - val_precision_1: 0.8779 - val_recall_1: 0.8167 - val_true_positives_1: 410.0000 - val_true_negatives_1: 720.0000 - val_false_positives_1: 57.0000 - val_false_negatives_1: 92.0000
# Epoch 11/20
# 348/348 [==============================] - 324s 932ms/step - loss: 0.0355 - binary_accuracy: 0.9915 - accuracy: 0.1646 - auc_1: 0.9981 - precision_1: 0.9912 - recall_1: 0.9906 - true_positives_1: 5162.0000 - true_negatives_1: 5878.0000 - false_positives_1: 46.0000 - false_negatives_1: 49.0000 - val_loss: 0.7684 - val_binary_accuracy: 0.8593 - val_accuracy: 0.1517 - val_auc_1: 0.9159 - val_precision_1: 0.7845 - val_recall_1: 0.8845 - val_true_positives_1: 444.0000 - val_true_negatives_1: 655.0000 - val_false_positives_1: 122.0000 - val_false_negatives_1: 58.0000
# Epoch 12/20
# 348/348 [==============================] - 1086s 3s/step - loss: 0.0422 - binary_accuracy: 0.9879 - accuracy: 0.1907 - auc_1: 0.9977 - precision_1: 0.9871 - recall_1: 0.9870 - true_positives_1: 5143.0000 - true_negatives_1: 5857.0000 - false_positives_1: 67.0000 - false_negatives_1: 68.0000 - val_loss: 0.6885 - val_binary_accuracy: 0.8929 - val_accuracy: 0.1517 - val_auc_1: 0.9311 - val_precision_1: 0.8476 - val_recall_1: 0.8865 - val_true_positives_1: 445.0000 - val_true_negatives_1: 697.0000 - val_false_positives_1: 80.0000 - val_false_negatives_1: 57.0000
# Epoch 13/20
# 348/348 [==============================] - 326s 937ms/step - loss: 0.0521 - binary_accuracy: 0.9853 - accuracy: 0.1996 - auc_1: 0.9970 - precision_1: 0.9856 - recall_1: 0.9829 - true_positives_1: 5122.0000 - true_negatives_1: 5849.0000 - false_positives_1: 75.0000 - false_negatives_1: 89.0000 - val_loss: 0.8421 - val_binary_accuracy: 0.8788 - val_accuracy: 0.1806 - val_auc_1: 0.9229 - val_precision_1: 0.8183 - val_recall_1: 0.8884 - val_true_positives_1: 446.0000 - val_true_negatives_1: 678.0000 - val_false_positives_1: 99.0000 - val_false_negatives_1: 56.0000
# Epoch 14/20
# 348/348 [==============================] - 331s 950ms/step - loss: 0.0441 - binary_accuracy: 0.9873 - accuracy: 0.2154 - auc_1: 0.9979 - precision_1: 0.9869 - recall_1: 0.9860 - true_positives_1: 5138.0000 - true_negatives_1: 5856.0000 - false_positives_1: 68.0000 - false_negatives_1: 73.0000 - val_loss: 0.8331 - val_binary_accuracy: 0.8905 - val_accuracy: 0.1798 - val_auc_1: 0.9296 - val_precision_1: 0.8901 - val_recall_1: 0.8227 - val_true_positives_1: 413.0000 - val_true_negatives_1: 726.0000 - val_false_positives_1: 51.0000 - val_false_negatives_1: 89.0000
# Epoch 15/20
# 348/348 [==============================] - 330s 950ms/step - loss: 0.0415 - binary_accuracy: 0.9899 - accuracy: 0.1771 - auc_1: 0.9977 - precision_1: 0.9900 - recall_1: 0.9885 - true_positives_1: 5151.0000 - true_negatives_1: 5872.0000 - false_positives_1: 52.0000 - false_negatives_1: 60.0000 - val_loss: 0.6456 - val_binary_accuracy: 0.8913 - val_accuracy: 0.1048 - val_auc_1: 0.9327 - val_precision_1: 0.8652 - val_recall_1: 0.8566 - val_true_positives_1: 430.0000 - val_true_negatives_1: 710.0000 - val_false_positives_1: 67.0000 - val_false_negatives_1: 72.0000
# Epoch 16/20
# 348/348 [==============================] - 339s 976ms/step - loss: 0.0262 - binary_accuracy: 0.9926 - accuracy: 0.1980 - auc_1: 0.9989 - precision_1: 0.9935 - recall_1: 0.9908 - true_positives_1: 5163.0000 - true_negatives_1: 5890.0000 - false_positives_1: 34.0000 - false_negatives_1: 48.0000 - val_loss: 0.7550 - val_binary_accuracy: 0.8890 - val_accuracy: 0.1822 - val_auc_1: 0.9288 - val_precision_1: 0.8309 - val_recall_1: 0.9004 - val_true_positives_1: 452.0000 - val_true_negatives_1: 685.0000 - val_false_positives_1: 92.0000 - val_false_negatives_1: 50.0000
# Epoch 17/20
# 348/348 [==============================] - 346s 996ms/step - loss: 0.0193 - binary_accuracy: 0.9951 - accuracy: 0.1957 - auc_1: 0.9991 - precision_1: 0.9946 - recall_1: 0.9948 - true_positives_1: 5184.0000 - true_negatives_1: 5896.0000 - false_positives_1: 28.0000 - false_negatives_1: 27.0000 - val_loss: 0.7196 - val_binary_accuracy: 0.8890 - val_accuracy: 0.1658 - val_auc_1: 0.9274 - val_precision_1: 0.8644 - val_recall_1: 0.8506 - val_true_positives_1: 427.0000 - val_true_negatives_1: 710.0000 - val_false_positives_1: 67.0000 - val_false_negatives_1: 75.0000
# Epoch 18/20
# 348/348 [==============================] - 330s 948ms/step - loss: 0.0160 - binary_accuracy: 0.9956 - accuracy: 0.2101 - auc_1: 0.9992 - precision_1: 0.9952 - recall_1: 0.9954 - true_positives_1: 5187.0000 - true_negatives_1: 5899.0000 - false_positives_1: 25.0000 - false_negatives_1: 24.0000 - val_loss: 0.7363 - val_binary_accuracy: 0.8905 - val_accuracy: 0.1501 - val_auc_1: 0.9219 - val_precision_1: 0.8577 - val_recall_1: 0.8645 - val_true_positives_1: 434.0000 - val_true_negatives_1: 705.0000 - val_false_positives_1: 72.0000 - val_false_negatives_1: 68.0000
# Epoch 19/20
# 348/348 [==============================] - 326s 936ms/step - loss: 0.0229 - binary_accuracy: 0.9945 - accuracy: 0.2134 - auc_1: 0.9989 - precision_1: 0.9939 - recall_1: 0.9944 - true_positives_1: 5182.0000 - true_negatives_1: 5892.0000 - false_positives_1: 32.0000 - false_negatives_1: 29.0000 - val_loss: 0.8611 - val_binary_accuracy: 0.8710 - val_accuracy: 0.1876 - val_auc_1: 0.9271 - val_precision_1: 0.7941 - val_recall_1: 0.9064 - val_true_positives_1: 455.0000 - val_true_negatives_1: 659.0000 - val_false_positives_1: 118.0000 - val_false_negatives_1: 47.0000
# Epoch 20/20
# 348/348 [==============================] - 326s 936ms/step - loss: 0.0286 - binary_accuracy: 0.9919 - accuracy: 0.1696 - auc_1: 0.9985 - precision_1: 0.9917 - recall_1: 0.9910 - true_positives_1: 5164.0000 - true_negatives_1: 5881.0000 - false_positives_1: 43.0000 - false_negatives_1: 47.0000 - val_loss: 0.8213 - val_binary_accuracy: 0.8819 - val_accuracy: 0.0649 - val_auc_1: 0.9122 - val_precision_1: 0.8962 - val_recall_1: 0.7908 - val_true_positives_1: 397.0000 - val_true_negatives_1: 731.0000 - val_false_positives_1: 46.0000 - val_false_negatives_1: 105.0000

# %%
getresultssummary(history_2, '2')

# %%
x_3 =  keras.layers.Dense(256, activation='relu')(x)
x_3 =  keras.layers.Dense(128, activation='relu')(x_3)
x_3 =  keras.layers.Dense(64, activation='relu')(x_3)
x_3 =  keras.layers.Dense(32, activation='relu')(x_3)
x_3 =  keras.layers.Dense(16, activation='relu')(x_3)
outputs_3 = keras.layers.Dense(1, activation='sigmoid')(x_3)
model_3_1 = keras.Model(inputs, outputs_3)
model_3_2 = keras.Model(inputs, outputs_3)

# %%
model_3_1.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Accuracy(), keras.metrics.AUC(), keras.metrics.Precision(),keras.metrics.Recall(), 
                      keras.metrics.TruePositives(), keras.metrics.TrueNegatives(), keras.metrics.FalsePositives(), 
                    keras.metrics.FalseNegatives()])

# %%
history_3_1 = model_3_1.fit(data_pp, label, epochs=epochs_range, validation_data=(val_data_pp, val_label))
# Out:
# Epoch 1/20
# 348/348 [==============================] - 314s 898ms/step - loss: 0.3243 - binary_accuracy: 0.8646 - accuracy: 1.7961e-04 - auc_2: 0.9367 - precision_2: 0.8628 - recall_2: 0.8449 - true_positives_2: 4403.0000 - true_negatives_2: 5224.0000 - false_positives_2: 700.0000 - false_negatives_2: 808.0000 - val_loss: 0.2575 - val_binary_accuracy: 0.8913 - val_accuracy: 0.0000e+00 - val_auc_2: 0.9559 - val_precision_2: 0.8682 - val_recall_2: 0.8526 - val_true_positives_2: 428.0000 - val_true_negatives_2: 712.0000 - val_false_positives_2: 65.0000 - val_false_negatives_2: 74.0000
# Epoch 2/20
# 348/348 [==============================] - 334s 961ms/step - loss: 0.2219 - binary_accuracy: 0.9093 - accuracy: 8.9807e-05 - auc_2: 0.9697 - precision_2: 0.9083 - recall_2: 0.8968 - true_positives_2: 4673.0000 - true_negatives_2: 5452.0000 - false_positives_2: 472.0000 - false_negatives_2: 538.0000 - val_loss: 0.2932 - val_binary_accuracy: 0.8952 - val_accuracy: 0.0000e+00 - val_auc_2: 0.9481 - val_precision_2: 0.9259 - val_recall_2: 0.7968 - val_true_positives_2: 400.0000 - val_true_negatives_2: 745.0000 - val_false_positives_2: 32.0000 - val_false_negatives_2: 102.0000
# Epoch 3/20
# 348/348 [==============================] - 331s 950ms/step - loss: 0.1779 - binary_accuracy: 0.9306 - accuracy: 0.0013 - auc_2: 0.9803 - precision_2: 0.9339 - recall_2: 0.9165 - true_positives_2: 4776.0000 - true_negatives_2: 5586.0000 - false_positives_2: 338.0000 - false_negatives_2: 435.0000 - val_loss: 0.3164 - val_binary_accuracy: 0.8858 - val_accuracy: 0.0039 - val_auc_2: 0.9455 - val_precision_2: 0.8423 - val_recall_2: 0.8725 - val_true_positives_2: 438.0000 - val_true_negatives_2: 695.0000 - val_false_positives_2: 82.0000 - val_false_negatives_2: 64.0000
# Epoch 4/20
# 348/348 [==============================] - 330s 948ms/step - loss: 0.1404 - binary_accuracy: 0.9475 - accuracy: 0.0054 - auc_2: 0.9879 - precision_2: 0.9469 - recall_2: 0.9405 - true_positives_2: 4901.0000 - true_negatives_2: 5649.0000 - false_positives_2: 275.0000 - false_negatives_2: 310.0000 - val_loss: 0.3395 - val_binary_accuracy: 0.8858 - val_accuracy: 0.0078 - val_auc_2: 0.9433 - val_precision_2: 0.8603 - val_recall_2: 0.8466 - val_true_positives_2: 425.0000 - val_true_negatives_2: 708.0000 - val_false_positives_2: 69.0000 - val_false_negatives_2: 77.0000
# Epoch 5/20
# 348/348 [==============================] - 333s 956ms/step - loss: 0.0940 - binary_accuracy: 0.9663 - accuracy: 0.0303 - auc_2: 0.9939 - precision_2: 0.9661 - recall_2: 0.9618 - true_positives_2: 5012.0000 - true_negatives_2: 5748.0000 - false_positives_2: 176.0000 - false_negatives_2: 199.0000 - val_loss: 0.3817 - val_binary_accuracy: 0.8929 - val_accuracy: 0.0078 - val_auc_2: 0.9401 - val_precision_2: 0.8643 - val_recall_2: 0.8625 - val_true_positives_2: 433.0000 - val_true_negatives_2: 709.0000 - val_false_positives_2: 68.0000 - val_false_negatives_2: 69.0000
# Epoch 6/20
# 348/348 [==============================] - 2496s 7s/step - loss: 0.0695 - binary_accuracy: 0.9751 - accuracy: 0.0410 - auc_2: 0.9966 - precision_2: 0.9742 - recall_2: 0.9726 - true_positives_2: 5068.0000 - true_negatives_2: 5790.0000 - false_positives_2: 134.0000 - false_negatives_2: 143.0000 - val_loss: 0.5385 - val_binary_accuracy: 0.8866 - val_accuracy: 0.0188 - val_auc_2: 0.9286 - val_precision_2: 0.8774 - val_recall_2: 0.8267 - val_true_positives_2: 415.0000 - val_true_negatives_2: 719.0000 - val_false_positives_2: 58.0000 - val_false_negatives_2: 87.0000
# Epoch 7/20
# 348/348 [==============================] - 283s 814ms/step - loss: 0.0604 - binary_accuracy: 0.9793 - accuracy: 0.0918 - auc_2: 0.9972 - precision_2: 0.9790 - recall_2: 0.9766 - true_positives_2: 5089.0000 - true_negatives_2: 5815.0000 - false_positives_2: 109.0000 - false_negatives_2: 122.0000 - val_loss: 0.5687 - val_binary_accuracy: 0.8819 - val_accuracy: 0.0735 - val_auc_2: 0.9281 - val_precision_2: 0.8589 - val_recall_2: 0.8367 - val_true_positives_2: 420.0000 - val_true_negatives_2: 708.0000 - val_false_positives_2: 69.0000 - val_false_negatives_2: 82.0000
# Epoch 8/20
# 348/348 [==============================] - 317s 912ms/step - loss: 0.0553 - binary_accuracy: 0.9855 - accuracy: 0.0930 - auc_2: 0.9982 - precision_2: 0.9852 - recall_2: 0.9839 - true_positives_2: 5127.0000 - true_negatives_2: 5847.0000 - false_positives_2: 77.0000 - false_negatives_2: 84.0000 - val_loss: 0.6291 - val_binary_accuracy: 0.8835 - val_accuracy: 0.1360 - val_auc_2: 0.9280 - val_precision_2: 0.8537 - val_recall_2: 0.8486 - val_true_positives_2: 426.0000 - val_true_negatives_2: 704.0000 - val_false_positives_2: 73.0000 - val_false_negatives_2: 76.0000
# Epoch 9/20
# 348/348 [==============================] - 344s 988ms/step - loss: 0.0353 - binary_accuracy: 0.9872 - accuracy: 0.1355 - auc_2: 0.9988 - precision_2: 0.9873 - recall_2: 0.9854 - true_positives_2: 5135.0000 - true_negatives_2: 5858.0000 - false_positives_2: 66.0000 - false_negatives_2: 76.0000 - val_loss: 0.7659 - val_binary_accuracy: 0.8796 - val_accuracy: 0.1063 - val_auc_2: 0.9142 - val_precision_2: 0.8799 - val_recall_2: 0.8028 - val_true_positives_2: 403.0000 - val_true_negatives_2: 722.0000 - val_false_positives_2: 55.0000 - val_false_negatives_2: 99.0000
# Epoch 10/20
# 348/348 [==============================] - 428s 1s/step - loss: 0.0315 - binary_accuracy: 0.9883 - accuracy: 0.1490 - auc_2: 0.9988 - precision_2: 0.9887 - recall_2: 0.9864 - true_positives_2: 5140.0000 - true_negatives_2: 5865.0000 - false_positives_2: 59.0000 - false_negatives_2: 71.0000 - val_loss: 0.5632 - val_binary_accuracy: 0.8952 - val_accuracy: 0.1306 - val_auc_2: 0.9331 - val_precision_2: 0.8651 - val_recall_2: 0.8685 - val_true_positives_2: 436.0000 - val_true_negatives_2: 709.0000 - val_false_positives_2: 68.0000 - val_false_negatives_2: 66.0000
# Epoch 11/20
# 348/348 [==============================] - 319s 917ms/step - loss: 0.0247 - binary_accuracy: 0.9911 - accuracy: 0.1740 - auc_2: 0.9992 - precision_2: 0.9923 - recall_2: 0.9887 - true_positives_2: 5152.0000 - true_negatives_2: 5884.0000 - false_positives_2: 40.0000 - false_negatives_2: 59.0000 - val_loss: 0.7204 - val_binary_accuracy: 0.8898 - val_accuracy: 0.1024 - val_auc_2: 0.9236 - val_precision_2: 0.8832 - val_recall_2: 0.8287 - val_true_positives_2: 416.0000 - val_true_negatives_2: 722.0000 - val_false_positives_2: 55.0000 - val_false_negatives_2: 86.0000
# Epoch 12/20
# 348/348 [==============================] - 338s 973ms/step - loss: 0.0181 - binary_accuracy: 0.9934 - accuracy: 0.1782 - auc_2: 0.9994 - precision_2: 0.9950 - recall_2: 0.9908 - true_positives_2: 5163.0000 - true_negatives_2: 5898.0000 - false_positives_2: 26.0000 - false_negatives_2: 48.0000 - val_loss: 0.7317 - val_binary_accuracy: 0.8866 - val_accuracy: 0.1556 - val_auc_2: 0.9262 - val_precision_2: 0.8507 - val_recall_2: 0.8625 - val_true_positives_2: 433.0000 - val_true_negatives_2: 701.0000 - val_false_positives_2: 76.0000 - val_false_negatives_2: 69.0000
# Epoch 13/20
# 348/348 [==============================] - 329s 947ms/step - loss: 0.0243 - binary_accuracy: 0.9920 - accuracy: 0.1895 - auc_2: 0.9991 - precision_2: 0.9940 - recall_2: 0.9889 - true_positives_2: 5153.0000 - true_negatives_2: 5893.0000 - false_positives_2: 31.0000 - false_negatives_2: 58.0000 - val_loss: 0.6989 - val_binary_accuracy: 0.8858 - val_accuracy: 0.1009 - val_auc_2: 0.9214 - val_precision_2: 0.8546 - val_recall_2: 0.8546 - val_true_positives_2: 429.0000 - val_true_negatives_2: 704.0000 - val_false_positives_2: 73.0000 - val_false_negatives_2: 73.0000
# Epoch 14/20
# 348/348 [==============================] - 331s 953ms/step - loss: 0.0238 - binary_accuracy: 0.9922 - accuracy: 0.1687 - auc_2: 0.9992 - precision_2: 0.9933 - recall_2: 0.9900 - true_positives_2: 5159.0000 - true_negatives_2: 5889.0000 - false_positives_2: 35.0000 - false_negatives_2: 52.0000 - val_loss: 0.7591 - val_binary_accuracy: 0.8843 - val_accuracy: 0.1634 - val_auc_2: 0.9249 - val_precision_2: 0.8340 - val_recall_2: 0.8805 - val_true_positives_2: 442.0000 - val_true_negatives_2: 689.0000 - val_false_positives_2: 88.0000 - val_false_negatives_2: 60.0000
# Epoch 15/20
# 348/348 [==============================] - 336s 965ms/step - loss: 0.0292 - binary_accuracy: 0.9913 - accuracy: 0.1076 - auc_2: 0.9987 - precision_2: 0.9910 - recall_2: 0.9904 - true_positives_2: 5161.0000 - true_negatives_2: 5877.0000 - false_positives_2: 47.0000 - false_negatives_2: 50.0000 - val_loss: 0.7411 - val_binary_accuracy: 0.8788 - val_accuracy: 0.0305 - val_auc_2: 0.9187 - val_precision_2: 0.8881 - val_recall_2: 0.7908 - val_true_positives_2: 397.0000 - val_true_negatives_2: 727.0000 - val_false_positives_2: 50.0000 - val_false_negatives_2: 105.0000
# Epoch 16/20
# 348/348 [==============================] - 333s 957ms/step - loss: 0.0205 - binary_accuracy: 0.9927 - accuracy: 0.1673 - auc_2: 0.9994 - precision_2: 0.9940 - recall_2: 0.9904 - true_positives_2: 5161.0000 - true_negatives_2: 5893.0000 - false_positives_2: 31.0000 - false_negatives_2: 50.0000 - val_loss: 0.6898 - val_binary_accuracy: 0.8905 - val_accuracy: 0.1087 - val_auc_2: 0.9248 - val_precision_2: 0.8664 - val_recall_2: 0.8526 - val_true_positives_2: 428.0000 - val_true_negatives_2: 711.0000 - val_false_positives_2: 66.0000 - val_false_negatives_2: 74.0000
# Epoch 17/20
# 348/348 [==============================] - 331s 953ms/step - loss: 0.0219 - binary_accuracy: 0.9923 - accuracy: 0.2149 - auc_2: 0.9993 - precision_2: 0.9921 - recall_2: 0.9914 - true_positives_2: 5166.0000 - true_negatives_2: 5883.0000 - false_positives_2: 41.0000 - false_negatives_2: 45.0000 - val_loss: 0.9949 - val_binary_accuracy: 0.8804 - val_accuracy: 0.1001 - val_auc_2: 0.9030 - val_precision_2: 0.9205 - val_recall_2: 0.7610 - val_true_positives_2: 382.0000 - val_true_negatives_2: 744.0000 - val_false_positives_2: 33.0000 - val_false_negatives_2: 120.0000
# Epoch 18/20
# 348/348 [==============================] - 329s 946ms/step - loss: 0.0211 - binary_accuracy: 0.9934 - accuracy: 0.1870 - auc_2: 0.9994 - precision_2: 0.9942 - recall_2: 0.9916 - true_positives_2: 5167.0000 - true_negatives_2: 5894.0000 - false_positives_2: 30.0000 - false_negatives_2: 44.0000 - val_loss: 0.7345 - val_binary_accuracy: 0.8952 - val_accuracy: 0.1149 - val_auc_2: 0.9223 - val_precision_2: 0.8849 - val_recall_2: 0.8426 - val_true_positives_2: 423.0000 - val_true_negatives_2: 722.0000 - val_false_positives_2: 55.0000 - val_false_negatives_2: 79.0000
# Epoch 19/20
# 348/348 [==============================] - 359s 1s/step - loss: 0.0129 - binary_accuracy: 0.9951 - accuracy: 0.2388 - auc_2: 0.9996 - precision_2: 0.9954 - recall_2: 0.9941 - true_positives_2: 5180.0000 - true_negatives_2: 5900.0000 - false_positives_2: 24.0000 - false_negatives_2: 31.0000 - val_loss: 0.9840 - val_binary_accuracy: 0.8827 - val_accuracy: 0.2338 - val_auc_2: 0.9197 - val_precision_2: 0.8154 - val_recall_2: 0.9064 - val_true_positives_2: 455.0000 - val_true_negatives_2: 674.0000 - val_false_positives_2: 103.0000 - val_false_negatives_2: 47.0000
# Epoch 20/20
# 348/348 [==============================] - 323s 929ms/step - loss: 0.0176 - binary_accuracy: 0.9925 - accuracy: 0.2350 - auc_2: 0.9996 - precision_2: 0.9921 - recall_2: 0.9919 - true_positives_2: 5169.0000 - true_negatives_2: 5883.0000 - false_positives_2: 41.0000 - false_negatives_2: 42.0000 - val_loss: 0.9467 - val_binary_accuracy: 0.8843 - val_accuracy: 0.1345 - val_auc_2: 0.9136 - val_precision_2: 0.9194 - val_recall_2: 0.7729 - val_true_positives_2: 388.0000 - val_true_negatives_2: 743.0000 - val_false_positives_2: 34.0000 - val_false_negatives_2: 114.0000

# %%
getresultssummary(history_3_1, '3.1')

# %%
model_3_1.save('model_3_1.h5')

# %%
model_3_2.compile(optimizer=keras.optimizers.SGD(),
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Accuracy(), keras.metrics.AUC(), keras.metrics.Precision(),keras.metrics.Recall(), 
                      keras.metrics.TruePositives(), keras.metrics.TrueNegatives(), keras.metrics.FalsePositives(), 
                    keras.metrics.FalseNegatives()])

# %%
history_3_2 = model_3_2.fit(data_pp, label, epochs=epochs_range, validation_data=(val_data_pp, val_label))

# %%
getresultssummary(history_3_2, '3.2')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9c67a883-3918-439e-a462-2827f4672e07' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
